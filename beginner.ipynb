# %%
x = int(input("请输入一个整数："))
if x % 2 == 0:
    print(x, "是一个偶数")
else:
    print(x, "是一个奇数")
# Out:
# 10 是一个偶数

# %%
for i in range(1, 5):
    if i % 2 == 0:
        print(i, end = ' ')
# Out:
# 2 4

# %%
school_life = ['Research', 'lectures', 'homework', 'exams', 'gym', 'friends']
print(school_life)
print(school_life[-1])
print(school_life[1:5])
# Out:
# ['Research', 'lectures', 'homework', 'exams', 'gym', 'friends']
# friends
# ['lectures', 'homework', 'exams', 'gym']
